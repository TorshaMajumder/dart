# %%
import lightkurve as lk
import pandas as pd
import matplotlib.pyplot as plt
from read_tic import read_tic_ids_from_pickle
# %matplotlib inline

# %%
tic_ids = read_tic_ids_from_pickle()
print(len(tic_ids))
# Out:
# 5210

# %%
search_tic_id = lk.search_lightcurve(tic_ids[0], author=('SPOC', 'TESS-SPOC'))

# %%
search_tic_id
# Out:
# SearchResult containing 5 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 01 2018      SPOC     120   231663901      0.0
#   1 TESS Sector 01 2018 TESS-SPOC    1800   231663901      0.0
#   2 TESS Sector 27 2020      SPOC      20   231663901      0.0
#   3 TESS Sector 27 2020      SPOC     120   231663901      0.0
#   4 TESS Sector 27 2020 TESS-SPOC     600   231663901      0.0

# %%
tic_1= search_tic_id[0].download()

# %%
data_dict = {'time':tic_1.time, 'flux':
# Out:
# <Time object: scale='tdb' format='btjd' value=[1325.30034716 1325.30173604 1325.30312493 ... 1353.17759073 1353.17897957
#  1353.18036841]>

# %%
tic_1.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
len(tic_1)
# Out:
# 18279

# %%
tic_1 = tic_1.remove_nans()

# %%
len(tic_1)
# Out:
# 18277

# %%
tic_1
# Out:
# <TessLightCurve length=18279 LABEL="TIC 231663901" SECTOR=1 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#       object          float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1325.3003471613704  1.7393037e+03 ...  3.2662433e-02  5.6904610e-02
#  1325.301736044114  1.7425652e+03 ...  5.2451799e-03  2.6888927e-02
#  1325.303124926392  1.7447987e+03 ...  1.0661460e-03  2.2642510e-02
# 1325.3045138091354  1.7343436e+03 ... -3.5521583e-04  1.1291002e-02
#  1325.305902691879  1.7345586e+03 ... -4.8702415e-03  1.2578744e-02
#  1325.307291574157  1.7334811e+03 ... -5.5124681e-03  1.2625867e-02
# 1325.3086804569004  1.7442643e+03 ... -4.8244996e-03  7.7017606e-03
# 1325.3100693391782  1.7467191e+03 ... -7.6040826e-03  1.1488601e-02
# 1325.3114582219218  1.7365874e+03 ... -7.1183429e-03  9.7787948e-03
# ...

# %%
x = tic_1.flatten(window_length=201).remove_outliers().fold(period=1.4294429, epoch_time=1326.4803471613704)

# %%
x.scatter()
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
x
# Out:
# <FoldedLightCurve length=18275 LABEL="TIC 231663901" SECTOR=1 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#         time             flux      ...   pos_corr1      pos_corr2
#                      electron / s  ...      pix            pix
#        object          float64     ...    float32        float32
# ------------------- -------------- ... -------------- --------------
# -0.7146158420586963  1.0021295e+00 ...  8.4822550e-02 -6.0571223e-02
# -0.7144788013785122  1.0008272e+00 ...  2.5894344e-02 -1.2030172e-02
# -0.7144139864087682  1.0022824e+00 ...  7.3027588e-02 -3.9559893e-02
# -0.7142940701522834  1.0006569e+00 ...  8.9202747e-02 -4.1559573e-02
# -0.7142623040749796  9.9312948e-01 ...  3.4353979e-02 -2.4658494e-02
#  -0.714190616568237  1.0056528e+00 ...  1.9639477e-02 -1.9585602e-03
# -0.7141010699473554  1.0000377e+00 ...  7.4496336e-02 -3.0594468e-02
# -0.7139661634623028  1.0040120e+00 ...  3.3119369e-02 -1.8057838e-02
# ...

# %%
x=x.to_pandas()

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x=x.reset_index()
x
# Out:
#            time      flux  flux_err                 time_original  timecorr  \
# 0     -0.714616  1.002130  0.004193 2018-08-20 23:53:48.784068535  0.004146
# 1     -0.714479  1.000827  0.004286 2018-07-31 23:36:26.492543303  0.004574
# 2     -0.714414  1.002282  0.004258 2018-08-13 20:22:06.891596689  0.004353
# 3     -0.714294  1.000657  0.004226 2018-08-19 13:35:52.718601249  0.004191
# 4     -0.714262  0.993129  0.004196 2018-08-06 16:50:20.664150328  0.004509
# ...         ...       ...       ...                           ...       ...
# 18270  0.714503  0.993988  0.004208 2018-08-22 10:11:44.625639228  0.004098
# 18271  0.714575  0.993410  0.004244 2018-08-09 13:26:16.064811486  0.004457
# 18272  0.714674  1.000691  0.004269 2018-08-02 09:54:25.294577981  0.004561
# 18273  0.714714  0.997762  0.004253 2018-08-15 06:40:03.579789907  0.004315
# 18274  0.714718  1.001814  0.004345 2018-07-26 06:22:29.800658959  0.004610
#
# ...

# %%
x= x[['time','flux','flux_err']]
x
# Out:
#            time      flux  flux_err
# 0     -0.714616  1.002130  0.004193
# 1     -0.714479  1.000827  0.004286
# 2     -0.714414  1.002282  0.004258
# 3     -0.714294  1.000657  0.004226
# 4     -0.714262  0.993129  0.004196
# ...         ...       ...       ...
# 18270  0.714503  0.993988  0.004208
# 18271  0.714575  0.993410  0.004244
# 18272  0.714674  1.000691  0.004269
# 18273  0.714714  0.997762  0.004253
# 18274  0.714718  1.001814  0.004345
#
# [18275 rows x 3 columns]
