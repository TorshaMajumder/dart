# %%
import os
import pickle
import hdbscan
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IForest import read_data_samples
from sklearn.decomposition import KernelPCA

# %%
# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.5, 's' : 80, 'linewidths':0}

# %%
def read_data_samples():

    with open('data/lightcurves.pickle', 'rb') as file:
        lightcurves = pickle.load(file)

    filtered_lcs = lightcurves['pca']
    flux = filtered_lcs['flux_pca']
#     flux = lightcurves['flux']

    return flux

# %%
data = read_data_samples()

# %%
data.shape
# Out:
# (3873, 300)

# %%
# data = pd.DataFrame(data)
# data.head()

# %%
PCA_Estimator = KernelPCA(n_components=2, kernel='rbf',
                                gamma=0.001, alpha=0.001,
                                fit_inverse_transform=True,
                                n_jobs=-1)

# %%
transformed_data = PCA_Estimator.fit_transform(data, y=None)

# %%
transformed_data.shape
# Out:
# (3873, 2)

# %%
plt.scatter(transformed_data.T[0], transformed_data.T[1], color='b', **plot_kwds)

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=60, min_samples=15,gen_min_span_tree=True)

# %%
clusterer.fit(transformed_data)
# Out:
# HDBSCAN(gen_min_span_tree=True, min_cluster_size=60, min_samples=15)

# %%
clusterer.labels_
# Out:
# array([ 0,  0,  0, ..., -1,  0,  1])

# %%
clusterer.labels_.max()
# Out:
# 1

# %%
clusterer.probabilities_
# Out:
# array([0.42375277, 0.77914338, 0.67313408, ..., 0.        , 0.28771206,
#        0.89275112])

# %%
clusterer.condensed_tree_

# %%
clusterer.condensed_tree_.plot()
# Out:
# <AxesSubplot:ylabel='$\\lambda$ value'>

# %%
clusterer.condensed_tree_.plot(select_clusters=True,
                               selection_palette=sns.color_palette('deep', 8))
# Out:
# <AxesSubplot:ylabel='$\\lambda$ value'>

# %%
clusterer.minimum_spanning_tree_.plot(edge_cmap='viridis',
                                      edge_alpha=0.6,
                                      node_size=80,
                                      edge_linewidth=2)
# Out:
# <AxesSubplot:>

# %%
clusterer.single_linkage_tree_.plot(cmap='viridis', colorbar=True)
# Out:
# <AxesSubplot:ylabel='distance'>

# %%
palette = sns.color_palette()
cluster_colors = [sns.desaturate(palette[col], sat)
                  if col >= 0 else (0.5, 0.5, 0.5) for col, sat in
                  zip(clusterer.labels_, clusterer.probabilities_)]
plt.scatter(transformed_data.T[0], transformed_data.T[1], c=cluster_colors, **plot_kwds)

# %%
g = clusterer.condensed_tree_.to_networkx()
g.number_of_nodes()
# Out:
# 3880

# %%
clusterer.condensed_tree_.to_pandas().head()
# Out:
#    parent  child  lambda_val  child_size
# 0    3873    947    4.564071           1
# 1    3873   1104    4.737078           1
# 2    3873    560    4.967142           1
# 3    3873   1087    4.979351           1
# 4    3873   1749    4.994500           1

# %%
tree = clusterer.condensed_tree_.to_pandas()
cluster_tree = tree[tree.child_size > 1]
cluster_tree.head()
# Out:
#       parent  child  lambda_val  child_size
# 1133    3873   3874   65.014709         852
# 1134    3873   3875   65.014709        1888
# 3101    3875   3876  105.285025         193
# 3102    3875   3877  105.285025         581
# 3154    3877   3878  105.896691         358

# %%
cluster_tree.shape
# Out:
# (6, 4)

# %%
clusterer.outlier_scores_
# Out:
# array([0.57624723, 0.22085662, 0.32686592, ..., 0.69761419, 0.71228794,
#        0.10724888])

# %%
sns.distplot(clusterer.outlier_scores_[np.isfinite(clusterer.outlier_scores_)], rug=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
threshold = pd.Series(clusterer.outlier_scores_).quantile(0.9)
outliers = np.where(clusterer.outlier_scores_ > threshold)[0]
outliers.shape
# Out:
# (388,)

# %%
plt.scatter(*transformed_data.T, s=50, linewidth=0, c='gray', alpha=0.25)
plt.scatter(*transformed_data[outliers].T, s=50, linewidth=0, c='red', alpha=0.5)
