# %%
import os
import re
import pickle
import numpy as np
import pandas as pd

# %%
ids = pd.read_csv("../transients/transient_ids.csv", header=None)
ids = ids[0].values.tolist()

# %%
ids[:10]
# Out:
# ['2021aetj',
#  '2020aeio',
#  '2020xu',
#  '2021paz',
#  '2018hyq',
#  '2019gg',
#  '2021ouk',
#  '2019thz',
#  '2020yef',
#  '2021loa']

# %%
with open("../transients/data/transients_info.pickle", 'rb') as file:
    data = pickle.load(file)

# %%
data.head(5)
# Out:
#    sector          ra        dec  magnitude at discovery  \
# 0       1  327.160083 -43.380019                  17.800
# 1       1  315.033417 -40.358594                  17.869
# 2       1  313.474583 -38.015594                  18.781
# 3       1  332.648000 -27.250161                  16.700
# 4       1  327.584333 -26.300131                  19.405
#
#    time of discovery in TESS JD  SN classification IAU name discovery survey  \
# 0                      1340.340  SN           SNIa  2018evo          ASAS-SN
# 1                      1341.926  SN           SNIa  2018exc            ATLAS
# 2                      1347.901  SN           SNII  2018fgb            ATLAS
# 3                      1331.630  SN           SNII  2018emt          ASAS-SN
# 4                      1337.965  AT   Unclassified  2018esp            ATLAS
#
#    cam  ccd    column       row
# 0    1    1  1860.105   322.643
# 1    1    1   528.652  1304.728
# 2    1    1   424.192  1751.547
# 3    1    3   642.568  1607.839
# 4    1    3  1303.439  1157.924

# %%
data.shape
# Out:
# (4400, 13)

# %%
data["classification"].value_counts().reset_index()
# Out:
#              index  classification
# 0     Unclassified            3899
# 1             SNIa             333
# 2             SNII              69
# 3    SNIa-91T-like              17
# 4               CV              16
# 5            SNIIn              13
# 6             SNIc               7
# 7             SNIb               5
# 8          SNIc-BL               4
# 9   SNIa-91bg-like               4
# 10           SNIbn               3
# 11             AGN               3
# 12          SLSN-I               3
# 13          Mdwarf               3
# 14           SNIIb               3
# 15           Other               3
# 16             SNI               3
# 17              SN               2
# 18         Varstar               2
# 19             FRB               2
# 20        SNIa-pec               1
# 21        SNII-pec               1
# 22            Nova               1
# 23           SNIIP               1
# 24          SNIb/c               1
# 25         SNIa-SC               1

# %%
data_ = data[data["IAU name"].isin(ids)]

# %%
data_.head()
# Out:
#    sector          ra        dec  magnitude at discovery  \
# 0       1  327.160083 -43.380019                  17.800
# 1       1  315.033417 -40.358594                  17.869
# 2       1  313.474583 -38.015594                  18.781
# 3       1  332.648000 -27.250161                  16.700
# 4       1  327.584333 -26.300131                  19.405
#
#    time of discovery in TESS JD  SN classification IAU name discovery survey  \
# 0                      1340.340  SN           SNIa  2018evo          ASAS-SN
# 1                      1341.926  SN           SNIa  2018exc            ATLAS
# 2                      1347.901  SN           SNII  2018fgb            ATLAS
# 3                      1331.630  SN           SNII  2018emt          ASAS-SN
# 4                      1337.965  AT   Unclassified  2018esp            ATLAS
#
#    cam  ccd    column       row
# 0    1    1  1860.105   322.643
# 1    1    1   528.652  1304.728
# 2    1    1   424.192  1751.547
# 3    1    3   642.568  1607.839
# 4    1    3  1303.439  1157.924

# %%
data_.shape
# Out:
# (3270, 13)

# %%
data__ = data_["classification"].value_counts().reset_index()

# %%
data__
# Out:
#              index  classification
# 0     Unclassified            2833
# 1             SNIa             287
# 2             SNII              64
# 3               CV              16
# 4    SNIa-91T-like              15
# 5            SNIIn              12
# 6             SNIc               7
# 7             SNIb               5
# 8          SNIc-BL               3
# 9            Other               3
# 10  SNIa-91bg-like               3
# 11             SNI               3
# 12             AGN               3
# 13          Mdwarf               3
# 14          SLSN-I               2
# 15           SNIbn               2
# 16              SN               2
# 17           SNIIb               1
# 18           SNIIP               1
# 19          SNIb/c               1
# 20        SNII-pec               1
# 21         Varstar               1
# 22        SNIa-pec               1
# 23         SNIa-SC               1

# %%
column = ['Label','Counts']

# %%
data__.columns=column

# %%
data__.head()
# Out:
#            Label  Counts
# 0   Unclassified    2833
# 1           SNIa     287
# 2           SNII      64
# 3             CV      16
# 4  SNIa-91T-like      15

# %%
group ={
'SNIa': ['SNIa', 'SNIa-91bg-like', 'SNIa-91T-like','SNIa-pec','SNIa-SC'],
'Others': ['CV','Mdwarf','Other','Varstar','SLSN-I'],
'AGN':['AGN'],
'SNIb/c':['SNIb/c', 'SNIc-BL','SNIbn', 'SNIc','SNIb','SNI'],
'SNII': ['SNII', 'SNIIn', 'SNIIb', 'SNIIP', 'SNII-pec'],
'SN': ['SN'],
'Unclassified': ['Unclassified']
}

# %%
group
# Out:
# {'SNIa': ['SNIa', 'SNIa-91bg-like', 'SNIa-91T-like', 'SNIa-pec', 'SNIa-SC'],
#  'Others': ['CV', 'Mdwarf', 'Other', 'Varstar', 'SLSN-I'],
#  'AGN': ['AGN'],
#  'SNIb/c': ['SNIb/c', 'SNIc-BL', 'SNIbn', 'SNIc', 'SNIb', 'SNI'],
#  'SNII': ['SNII', 'SNIIn', 'SNIIb', 'SNIIP', 'SNII-pec'],
#  'SN': ['SN'],
#  'Unclassified': ['Unclassified']}

# %%
group__ = list()
for i in range(len(data__)):
    #print(data__.loc[i,"Label"])
    for k,v in group.items():
        if (data__.loc[i,"Label"] in v):
            group__.append(k)

# %%
len(group__)
# Out:
# 24

# %%
group__
# Out:
# ['Unclassified',
#  'SNIa',
#  'SNII',
#  'Others',
#  'SNIa',
#  'SNII',
#  'SNIb/c',
#  'SNIb/c',
#  'SNIb/c',
#  'Others',
#  'SNIa',
#  'SNIb/c',
#  'AGN',
#  'Others',
#  'Others',
#  'SNIb/c',
#  'SN',
#  'SNII',
#  'SNII',
#  'SNIb/c',
#  'SNII',
#  'Others',
#  'SNIa',
#  'SNIa']

# %%
data__["Group"] = group__

# %%
data__
# Out:
#              Label  Counts         Group
# 0     Unclassified    2833  Unclassified
# 1             SNIa     287          SNIa
# 2             SNII      64          SNII
# 3               CV      16        Others
# 4    SNIa-91T-like      15          SNIa
# 5            SNIIn      12          SNII
# 6             SNIc       7        SNIb/c
# 7             SNIb       5        SNIb/c
# 8          SNIc-BL       3        SNIb/c
# 9            Other       3        Others
# 10  SNIa-91bg-like       3          SNIa
# 11             SNI       3        SNIb/c
# 12             AGN       3           AGN
# 13          Mdwarf       3        Others
# 14          SLSN-I       2        Others
# 15           SNIbn       2        SNIb/c
# 16              SN       2            SN
# 17           SNIIb       1          SNII
# 18           SNIIP       1          SNII
# 19          SNIb/c       1        SNIb/c
# 20        SNII-pec       1          SNII
# 21         Varstar       1        Others
# 22        SNIa-pec       1          SNIa
# 23         SNIa-SC       1          SNIa

# %%
data__.to_csv(path_or_buf="../transients/labels__.csv", header=True, index=False)
