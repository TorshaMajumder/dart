# %%
import pickle
import pandas as pd

# %%
with open("data/tsfresh_data.pickle", 'rb') as file:
            data = pickle.load(file)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#              FLUX__variance_larger_than_standard_deviation  \
# TOI 1000.01                                            0.0
# TOI 1001.01                                            0.0
# TOI 1002.01                                            0.0
# TOI 1003.01                                            1.0
# TOI 1004.01                                            0.0
#
#              FLUX__has_duplicate_max  FLUX__has_duplicate_min  \
# TOI 1000.01                      0.0                      0.0
# TOI 1001.01                      0.0                      0.0
# TOI 1002.01                      0.0                      0.0
# TOI 1003.01                      0.0                      0.0
# TOI 1004.01                      0.0                      0.0
#
#              FLUX__has_duplicate  FLUX__sum_values  FLUX__abs_energy  \
# TOI 1000.01                  1.0      4.263256e-14             300.0
# TOI 1001.01                  1.0     -2.131628e-14             300.0
# ...

# %%
nan_count = data.isna().sum()
nan_count
# Out:
# FLUX__variance_larger_than_standard_deviation              0
# FLUX__has_duplicate_max                                    0
# FLUX__has_duplicate_min                                    0
# FLUX__has_duplicate                                        0
# FLUX__sum_values                                           0
#                                                         ...
# ID__matrix_profile__feature_"mean"__threshold_0.98      3873
# ID__matrix_profile__feature_"median"__threshold_0.98    3873
# ID__matrix_profile__feature_"25"__threshold_0.98        3873
# ID__matrix_profile__feature_"75"__threshold_0.98        3873
# ID__mean_n_absolute_max__number_of_maxima_7                0
# Length: 1578, dtype: int64

# %%
data_1 = data.dropna(axis='columns')

# %%
len(data_1.columns)
# Out:
# 1503

# %%
nan_count = data_1.isna().sum()
nan_count
# Out:
# FLUX__variance_larger_than_standard_deviation    0
# FLUX__has_duplicate_max                          0
# FLUX__has_duplicate_min                          0
# FLUX__has_duplicate                              0
# FLUX__sum_values                                 0
#                                                 ..
# ID__permutation_entropy__dimension_4__tau_1      0
# ID__permutation_entropy__dimension_5__tau_1      0
# ID__permutation_entropy__dimension_6__tau_1      0
# ID__permutation_entropy__dimension_7__tau_1      0
# ID__mean_n_absolute_max__number_of_maxima_7      0
# Length: 1503, dtype: int64

# %%
data_1 = data_1.dropna()

# %%
nan_count = data_1.isna().sum()
nan_count
# Out:
# FLUX__variance_larger_than_standard_deviation    0
# FLUX__has_duplicate_max                          0
# FLUX__has_duplicate_min                          0
# FLUX__has_duplicate                              0
# FLUX__sum_values                                 0
#                                                 ..
# ID__permutation_entropy__dimension_4__tau_1      0
# ID__permutation_entropy__dimension_5__tau_1      0
# ID__permutation_entropy__dimension_6__tau_1      0
# ID__permutation_entropy__dimension_7__tau_1      0
# ID__mean_n_absolute_max__number_of_maxima_7      0
# Length: 1503, dtype: int64

# %%
data_1.head()
# Out:
#              FLUX__variance_larger_than_standard_deviation  \
# TOI 1000.01                                            0.0
# TOI 1001.01                                            0.0
# TOI 1002.01                                            0.0
# TOI 1003.01                                            1.0
# TOI 1004.01                                            0.0
#
#              FLUX__has_duplicate_max  FLUX__has_duplicate_min  \
# TOI 1000.01                      0.0                      0.0
# TOI 1001.01                      0.0                      0.0
# TOI 1002.01                      0.0                      0.0
# TOI 1003.01                      0.0                      0.0
# TOI 1004.01                      0.0                      0.0
#
#              FLUX__has_duplicate  FLUX__sum_values  FLUX__abs_energy  \
# TOI 1000.01                  1.0      4.263256e-14             300.0
# TOI 1001.01                  1.0     -2.131628e-14             300.0
# ...
